# %%
# !git clone https://github.com/Yurnero58/music-generation-unsupervised.git
# %cd music-generation-unsupervised
# !pip install pretty_midi torch numpy matplotlib
# Out:
# Cloning into 'music-generation-unsupervised'...
# remote: Enumerating objects: 606, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 606 (delta 66), reused 181 (delta 34), pack-reused 391 (from 1)
# Receiving objects: 100% (606/606), 8.74 MiB | 12.65 MiB/s, done.
# Resolving deltas: 100% (279/279), done.
# /content/music-generation-unsupervised/music-generation-unsupervised
# ...

# %% [markdown]
# # **Task-1: LSTM Autoencoder**

# %%
# !mkdir -p data/raw_midi
# !wget https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# !unzip -q maestro-v3.0.0-midi.zip -d data/raw_midi/
# Out:
# --2026-04-24 08:26:37--  https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.137.207, 142.250.101.207, 142.250.141.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.137.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58416533 (56M) [application/octet-stream]
# Saving to: ‘maestro-v3.0.0-midi.zip’
#
# maestro-v3.0.0-midi 100%[===================>]  55.71M   190MB/s    in 0.3s
#
# 2026-04-24 08:26:37 (190 MB/s) - ‘maestro-v3.0.0-midi.zip’ saved [58416533/58416533]

# %%
# %cd /content/music-generation-unsupervised
# !git pull origin main
# Out:
# /content/music-generation-unsupervised
# From https://github.com/Yurnero58/music-generation-unsupervised
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python -m src.preprocessing.midi_parser
# Out:
# Found 1276 files. Starting preprocessing with silence filtering...
# Success! Saved 44074 active music sequences.
# Filtered out 36 silent/empty sequences.

# %%
# !python -m src.training.train_ae
# Out:
# Starting Autoregressive Training on: cuda
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/music-generation-unsupervised/src/training/train_ae.py", line 57, in <module>
#     train()
#   File "/content/music-generation-unsupervised/src/training/train_ae.py", line 17, in train
#     optimizer = optim.Adam(model.parameters(), lr=0.001)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/adam.py", line 102, in __init__
#     super().__init__(params, defaults)
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 408, in __init__
#     self.add_param_group(cast(dict, param_group))
#   File "/usr/local/lib/python3.12/dist-packages/torch/_compile.py", line 47, in inner
#     import torch._dynamo
# ...

# %%
# !python -m src.generation.generate_task1
# Out:
# Initiating Guided Reconstruction Protocol (Task 1)...
# Generated: /content/music-generation-unsupervised/outputs/generated_midis/task1_reconstruction_1.mid
# Generated: /content/music-generation-unsupervised/outputs/generated_midis/task1_reconstruction_2.mid
# Generated: /content/music-generation-unsupervised/outputs/generated_midis/task1_reconstruction_3.mid
# Generated: /content/music-generation-unsupervised/outputs/generated_midis/task1_reconstruction_4.mid
# Generated: /content/music-generation-unsupervised/outputs/generated_midis/task1_reconstruction_5.mid

# %%
# %cd /content/music-generation-unsupervised
# !git pull origin main
# Out:
# /content/music-generation-unsupervised
# From https://github.com/Yurnero58/music-generation-unsupervised
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # **Task-2: Variable Autoencoder (VAE)**

# %%
# Create directory and download from the Columbia mirror
# !mkdir -p data/raw_midi/lakh_clean
# !wget -O lakh_clean.tar.gz http://hog.ee.columbia.edu/craffel/lmd/clean_midi.tar.gz
# !tar -xzf lakh_clean.tar.gz -C data/raw_midi/lakh_clean --strip-components=1
# Out:
# --2026-04-24 04:58:27--  http://hog.ee.columbia.edu/craffel/lmd/clean_midi.tar.gz
# Resolving hog.ee.columbia.edu (hog.ee.columbia.edu)... 128.59.66.5
# Connecting to hog.ee.columbia.edu (hog.ee.columbia.edu)|128.59.66.5|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 234283029 (223M) [application/x-gzip]
# Saving to: ‘lakh_clean.tar.gz’
#
# lakh_clean.tar.gz   100%[===================>] 223.43M  11.2MB/s    in 20s
#
# 2026-04-24 04:58:47 (11.0 MB/s) - ‘lakh_clean.tar.gz’ saved [234283029/234283029]

# %%
# !python -m src.preprocessing.midi_parser_mg
# Out:
# Found 2198 artist folders. Processing...
# /usr/local/lib/python3.12/dist-packages/pretty_midi/pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Task 2 Dataset Ready: 8176 segments saved to data/processed/multi_genre_lmd.npy

# %%
# !git pull origin main
# %env PYTHONPATH = /content/music-generation-unsupervised/src
# Out:
# From https://github.com/Yurnero58/music-generation-unsupervised
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# env: PYTHONPATH=/content/music-generation-unsupervised/src

# %%
# !python /content/music-generation-unsupervised/src/training/train_vae.py
# Out:
# Final Attempt: Force-Reconstruction Training on cuda...
# Epoch 1/30 | Loss: 1003.1309 | Beta: 0.0
# Epoch 2/30 | Loss: 827.4535 | Beta: 0.0
# Epoch 3/30 | Loss: 709.3783 | Beta: 0.0
# Epoch 4/30 | Loss: 658.9897 | Beta: 0.0
# Epoch 5/30 | Loss: 623.2914 | Beta: 0.0
# Epoch 6/30 | Loss: 598.1298 | Beta: 0.0
# Epoch 7/30 | Loss: 578.8727 | Beta: 0.0
# Epoch 8/30 | Loss: 565.5733 | Beta: 0.0
# Epoch 9/30 | Loss: 554.5407 | Beta: 0.0
# Epoch 10/30 | Loss: 544.7280 | Beta: 0.0
# Epoch 11/30 | Loss: 539.9821 | Beta: 0.0
# Epoch 12/30 | Loss: 534.0259 | Beta: 0.0
# Epoch 13/30 | Loss: 531.1302 | Beta: 0.0
# Epoch 14/30 | Loss: 526.0262 | Beta: 0.0
# Epoch 15/30 | Loss: 523.9963 | Beta: 0.0
# Epoch 16/30 | Loss: 521.2052 | Beta: 0.001
# Epoch 17/30 | Loss: 515.1694 | Beta: 0.001
# Epoch 18/30 | Loss: 512.0388 | Beta: 0.001
# Epoch 19/30 | Loss: 506.9797 | Beta: 0.001
# Epoch 20/30 | Loss: 503.4491 | Beta: 0.001
# Epoch 21/30 | Loss: 500.9745 | Beta: 0.001
# ...

# %%
# !python /content/music-generation-unsupervised/src/generation/generate_vae.py

# %% [markdown]
# # **Task-3: Transformer**

# %%
# %cd /content/music-generation-unsupervised
# !git pull origin main
# Out:
# /content/music-generation-unsupervised
# From https://github.com/Yurnero58/music-generation-unsupervised
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# %cd /content/music-generation-unsupervised
# !python src/preprocessing/build_transformer_dataset.py
# Out:
# /content/music-generation-unsupervised
# Found 2198 artist folders. Extracting sequences...
# /usr/local/lib/python3.12/dist-packages/pretty_midi/pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Tokenizer vocabulary saved to /content/music-generation-unsupervised/data/processed/tokenizer_vocab.pkl
# Task 3 Dataset Ready: 8564012 total tokens saved to /content/music-generation-unsupervised/data/processed/transformer_tokens.npy

# %%
# %cd /content/music-generation-unsupervised
# !python src/training/train_transformer.py
# Out:
# /content/music-generation-unsupervised
# Training on cuda...
# Tokenizer vocabulary loaded successfully.
# Loading dataset from /content/music-generation-unsupervised/data/processed/transformer_tokens.npy...
# Total sequences: 33453 | Total batches per epoch: 523
# Epoch 1/20: 100% 523/523 [02:17<00:00,  3.82it/s, Loss=2.9369]
# End of Epoch 1 | Avg Loss: 3.4016 | Perplexity: 30.01
#
# Epoch 2/20: 100% 523/523 [02:17<00:00,  3.81it/s, Loss=2.8164]
# End of Epoch 2 | Avg Loss: 2.9255 | Perplexity: 18.64
#
# Epoch 3/20: 100% 523/523 [02:17<00:00,  3.80it/s, Loss=2.8039]
# End of Epoch 3 | Avg Loss: 2.7741 | Perplexity: 16.02
#
# Epoch 4/20: 100% 523/523 [02:17<00:00,  3.80it/s, Loss=2.6283]
# End of Epoch 4 | Avg Loss: 2.6669 | Perplexity: 14.39
#
# Epoch 5/20: 100% 523/523 [02:17<00:00,  3.80it/s, Loss=2.5344]
# End of Epoch 5 | Avg Loss: 2.5876 | Perplexity: 13.30
#
# Epoch 6/20: 100% 523/523 [02:17<00:00,  3.81it/s, Loss=2.4430]
# ...

# %%
# %cd /content/music-generation-unsupervised
# !python src/generation/generate_transformer.py
# Out:
# [Errno 2] No such file or directory: '/content/music-generation-unsupervised'
# /content
# python3: can't open file '/content/src/generation/generate_transformer.py': [Errno 2] No such file or directory

# %%
# %cd /content/music-generation-unsupervised
# !git fetch --all
# !git reset --hard origin/main
# Out:
# /content/music-generation-unsupervised
# Fetching origin
# Updating files: 100% (11/11), done.
# HEAD is now at 5fd31ad Final submission: Added Random and Markov baselines, RLHF outputs, and LFS tracking

# %% [markdown]
# # Task-4: Reinforce Learning

# %%
# !python src/models/reward_model.py
# Out:
# Tokenizer vocabulary loaded successfully.
# Loaded dynamic vocab size: 392
# Training Reward Model on cuda with vocab size 392...
# RM Epoch 1/20 | Avg MSE Loss: 39.6610
# RM Epoch 2/20 | Avg MSE Loss: 37.5712
# RM Epoch 3/20 | Avg MSE Loss: 35.2661
# RM Epoch 4/20 | Avg MSE Loss: 32.1400
# RM Epoch 5/20 | Avg MSE Loss: 25.4141
# RM Epoch 6/20 | Avg MSE Loss: 15.3945
# RM Epoch 7/20 | Avg MSE Loss: 4.7884
# RM Epoch 8/20 | Avg MSE Loss: 6.0099
# RM Epoch 9/20 | Avg MSE Loss: 4.9681
# RM Epoch 10/20 | Avg MSE Loss: 3.1184
# RM Epoch 11/20 | Avg MSE Loss: 3.2047
# RM Epoch 12/20 | Avg MSE Loss: 2.2414
# RM Epoch 13/20 | Avg MSE Loss: 1.5246
# RM Epoch 14/20 | Avg MSE Loss: 0.9535
# RM Epoch 15/20 | Avg MSE Loss: 0.6075
# RM Epoch 16/20 | Avg MSE Loss: 0.2773
# RM Epoch 17/20 | Avg MSE Loss: 0.2562
# RM Epoch 18/20 | Avg MSE Loss: 0.2027
# RM Epoch 19/20 | Avg MSE Loss: 0.0802
# RM Epoch 20/20 | Avg MSE Loss: 0.0331
# Reward Model Saved and ready for RLHF.

# %%
# !python src/training/train_rlhf.py
# Out:
# Starting RLHF on cuda...
# Tokenizer vocabulary loaded successfully.
# RL Fine-tuning: 100% 500/500 [04:57<00:00,  1.68it/s, Reward=5.31, Advantage=-0.24]
#
# RLHF Tuning Complete.

# %%
# %cd /content/music-generation-unsupervised
# !python src/generation/generate_rl.py
# Out:
# /content/music-generation-unsupervised
# Tokenizer vocabulary loaded successfully.
# Generating 10 long-sequence compositions for Human Feedback...
# Saved: /content/music-generation-unsupervised/outputs/transformer1/composition_1.mid AND /content/music-generation-unsupervised/outputs/transformer1/composition_1.npy
# Saved: /content/music-generation-unsupervised/outputs/transformer1/composition_2.mid AND /content/music-generation-unsupervised/outputs/transformer1/composition_2.npy
# Saved: /content/music-generation-unsupervised/outputs/transformer1/composition_3.mid AND /content/music-generation-unsupervised/outputs/transformer1/composition_3.npy
# Saved: /content/music-generation-unsupervised/outputs/transformer1/composition_4.mid AND /content/music-generation-unsupervised/outputs/transformer1/composition_4.npy
# Saved: /content/music-generation-unsupervised/outputs/transformer1/composition_5.mid AND /content/music-generation-unsupervised/outputs/transformer1/composition_5.npy
# ...

# %%
# %cd /content/music-generation-unsupervised
# !git add src/
# !git add -f data/processed/human_feedback.csv
# !git add outputs/transformer1/*.mid
# Out:
# /content/music-generation-unsupervised

# %%
# %cd /content/music-generation-unsupervised
# !git pull origin main
# Out:
# /content/music-generation-unsupervised
# From https://github.com/Yurnero58/music-generation-unsupervised
#  * branch            main       -> FETCH_HEAD
#    5fd31ad..cc4d624  main       -> origin/main
# Already up to date.

# %% [markdown]
# # **Baseline: Random Note Generator (Naive)**

# %%
# !python src/generation/generate_random.py
# Out:
# --- Generating Naive Random Baseline ---
# Loading vocabulary from: /content/music-generation-unsupervised/data/processed/tokenizer_vocab.pkl
# Tokenizer vocabulary loaded successfully.
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_1.mid
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_2.mid
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_3.mid
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_4.mid
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_5.mid
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_6.mid
# Successfully generated: /content/music-generation-unsupervised/outputs/baseline_random/random_7.mid
# ...

# %% [markdown]
# # **Baseline: Markov Chain Music Model**

# %%
# !python src/generation/generate_markov.py
# Out:
# Tokenizer vocabulary loaded successfully.
# Training Markov Chain from dataset...
# --- Generating 10 Markov Compositions ---
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_1.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_2.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_3.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_4.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_5.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_6.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_7.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_8.mid
# Generated: /content/music-generation-unsupervised/outputs/baseline_markov/markov_9.mid
# ...
